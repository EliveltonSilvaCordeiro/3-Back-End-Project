# %% [markdown]
# # Project 3 | Weather Forecast API
#
# **"The aim of this challenge is to write a computer program to display a 5-day weather forecast for a specific location chosen by the end-user."**
#
# &nbsp;
#
# For this project, I will be using **requests** and **json** to access the data and **datetime** to retrieve "UNIX" formatted data <br>
# Now, the objectives of the challenge are:
#
# &nbsp;
#
# >1. <a href=#Retrive-the-city-from-the-end-user-(input)>`Retrieve the city from the end user (input)`</a>
# <br><br>
# >2. <a href=#Use-the-Open-Weather-Map-API-to-retrieve-an-up-to-date-weather-forecast-for-this-city>`Use the Open Weather Map API to retrieve an up-to-date weather forecast for this city`</a>
# <br><br>
# >3. <a href=#Parse-the-retrieved-information>`Parse the retrieved information`</a>
# <br><br>
# >4. <a href=#Display-the-5-day-weather-forecast-for-the-selected-location.-(output)>`Display the 5-day weather forecast for the selected location. (output)`</a>
#
# &nbsp;
#
# **The jupyter notebook will serve to separate the challenge phases**
#
# ##### PS: To run this code, you will need your own API key in the <a href=https://home.openweathermap.org/users/sign_in target=_blank>Open Weather Map</a>

# %% [markdown]
# ## Retrive the city from the end user (input)
#
# As it suggests, just store the user's input in a variable and add it in the API call link, after that we proceed
#
# - Call the API
# - Transform JSON in a Python dictionary
#
# <a href=#Project-3-|-Weather-Forecast-API>Return to the top here</a>

# %%
import requests
import json

api_key = input("Type your API key of Open Weather Map: ")
city = input("Forecast which city?: ")

call_link = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&units=imperial&appid={api_key}"

json_requisition = requests.get(call_link)
forecast_info = json.loads(json_requisition.text)
# Out:
# Type your API key of Open Weather Map:  16fa16229a918b8bb90264da6ef6f79b
# Forecast which city?:  Nevada

# %% [markdown]
# ## Use the Open Weather Map API to retrieve an up-to-date weather forecast for this city
#
# I thought it would be better to display the data <a href=#Displaying-Requested-Data> in the Test Zone</a>, I am already using Open Weather API, so let's add an error control for the user's input then proceed
#
# - control error with **if** (any response code besides **200** is an error).
#
# <a href=#Project-3-|-Weather-Forecast-API>Return to the top here</a>

# %%
response_code = forecast_info['cod']

if response_code == "200":
    pass

else:
    print(f"""\nCode Error: {forecast_info['cod']} \nSee "https://openweathermap.org/faq" for more details""")
    exit()

# %% [markdown]
# ## Parse the retrieved information
#
# Analyze the requested data and parse information that I considered important for the forecast
#
# - identifying data <a href=#Testing-Parsed-Values> in the Test Zone</a>
# - storing data in variables and functions (the reason for this will be clear in the last objective)
#
# <a href=#Project-3-|-Weather-Forecast-API>Return to the top here</a>

# %%
import datetime

country = forecast_info['city']['country']

city = forecast_info['city']['name']

city_id = forecast_info['city']['id']

latitude, longtude = forecast_info['city']['coord']['lat'], forecast_info['city']['coord']['lon']

population = forecast_info['city']['population']

timezone = forecast_info['city']['timezone']/3600

#--------------------------------------------------------------------------------------------------

def unix_timestamp_conversion (unix_time):
    unix = int(unix_time)
 
    date_time = datetime.datetime.fromtimestamp(unix)

    converted_time = date_time.strftime('%Y-%m-%d %H:%M:%S')

    return converted_time

sunrise = unix_timestamp_conversion(forecast_info['city']['sunrise'])

sunset = unix_timestamp_conversion(forecast_info['city']['sunset'])

#--------------------------------------------------------------------------------------------------

def date_and_time (index):
    dt_txt_data = forecast_info['list'][index]['dt_txt']
    return dt_txt_data

def weather (index):
    weather_data = forecast_info['list'][index]['weather'][0]['main']
    return weather_data

def descripition (index):
    descripition_data = forecast_info['list'][index]['weather'][0]['description']
    return descripition_data

#--------------------------------------------------------------------------------------------------

def temperature (index):
    temperature_data = forecast_info['list'][index]['main']['temp']
    return temperature_data

def minimal (index):
    temp_min_data = forecast_info['list'][index]['main']['temp_min']
    return temp_min_data
    
def maximum (index):
    temp_max_data = forecast_info['list'][index]['main']['temp_max']
    return temp_max_data

def feels_like (index):
    fells_like_data = forecast_info['list'][index]['main']['feels_like']
    return fells_like_data

#--------------------------------------------------------------------------------------------------

def clouds (index):
    cloads_data = forecast_info['list'][index]['wind']['speed']
    return cloads_data

def humidity (index):
    humidity_data = forecast_info['list'][index]['main']['humidity']
    return humidity_data

def visibility (index):
    visibility_data = forecast_info['list'][index]['visibility']
    return visibility_data

#--------------------------------------------------------------------------------------------------

def wind_spd (index):
    wind_speed_data = forecast_info['list'][index]['wind']['speed']
    return wind_speed_data

def wind_deg (index):
    wind_degrees_data = forecast_info['list'][index]['wind']['deg']
    return wind_degrees_data

def wind_gust (index):
    wind_gusts_data = forecast_info['list'][index]['wind']['gust']
    return wind_gusts_data

#--------------------------------------------------------------------------------------------------

def pressure (index):
    pressure_data = forecast_info['list'][index]['main']['pressure']
    return pressure_data

def sea_level (index):
    sea_level_data = forecast_info['list'][index]['main']['sea_level']
    return sea_level_data

def ground_level (index):
    ground_level_data = forecast_info['list'][index]['main']['grnd_level']
    return ground_level_data

# %% [markdown]
# ## Display the 5-day weather forecast for the selected location. (output)
#
# For the last part, print the parsed forecast
#
# - run a **for** loop to print all the next five days, including all days hours 3 by 3
#
# <a href=#Project-3-|-Weather-Forecast-API>Return to the top here</a>

# %%
print(f"""
Lat, Lon:     {latitude}, {longtude}
          
Country:      {country}
City:         {city}
City ID:      {city_id}

Timezone:     {timezone:.0f} hours
Population:   {population:,}

Sunrise:      {sunrise}
Sunset:       {sunset}
""")

max_index = len(forecast_info['list'])

for recorded_hours in range(1, max_index):
    print(f"""
-----------------------------------------
-----------{date_and_time(recorded_hours)}-----------
-----------------------------------------
Weather:            {weather      (recorded_hours)}
Descripition:       {descripition (recorded_hours)}
Temperature:        {temperature  (recorded_hours)} F°
Min and Max Temp:   {minimal      (recorded_hours)} F° - {maximum (recorded_hours)} F°
Feels Like:         {feels_like   (recorded_hours)} F°

Clouds:             {clouds       (recorded_hours)}%
Humidity:           {humidity     (recorded_hours)}%
Visibility:         {visibility   (recorded_hours)} mi                                          
Wind Speed:         {wind_spd     (recorded_hours)} mph
Wind Direction:     {wind_deg     (recorded_hours)}°
Wind Gust:          {wind_gust    (recorded_hours)} mph
                                        
Pressure:           {pressure     (recorded_hours)} hPa
Sea Level:          {sea_level    (recorded_hours)} hPa
Ground Level:       {ground_level (recorded_hours)} hPa
-----------------------------------------
""")
# Out:
# Lat, Lon:     39.2502, -116.7512
#
# Country:      US
# City:         Nevada
# City ID:      5509151
#
# Timezone:     -7 hours
# Population:   2,399,532
#
# Sunrise:      2022-07-10 12:29:20
# Sunset:       2022-07-11 03:15:01
#
#
# -----------------------------------------
# -----------2022-07-10 18:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        71.08 F°
# Min and Max Temp:   71.08 F° - 78.37 F°
# Feels Like:         68.63 F°
#
# Clouds:             6.89%
# Humidity:           16%
# Visibility:         10000 mi
# Wind Speed:         6.89 mph
# Wind Direction:     278°
# Wind Gust:          10.74 mph
#
# Pressure:           1019 hPa
# Sea Level:          1019 hPa
# Ground Level:       791 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-10 21:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        78.48 F°
# Min and Max Temp:   78.48 F° - 84 F°
# Feels Like:         76.64 F°
#
# Clouds:             11.01%
# Humidity:           13%
# Visibility:         10000 mi
# Wind Speed:         11.01 mph
# Wind Direction:     262°
# Wind Gust:          12.5 mph
#
# Pressure:           1017 hPa
# Sea Level:          1017 hPa
# Ground Level:       791 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 00:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        84.94 F°
# Min and Max Temp:   84.94 F° - 84.94 F°
# Feels Like:         81.86 F°
#
# Clouds:             7.67%
# Humidity:           9%
# Visibility:         10000 mi
# Wind Speed:         7.67 mph
# Wind Direction:     312°
# Wind Gust:          8.28 mph
#
# Pressure:           1012 hPa
# Sea Level:          1012 hPa
# Ground Level:       790 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 03:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        72.19 F°
# Min and Max Temp:   72.19 F° - 72.19 F°
# Feels Like:         69.82 F°
#
# Clouds:             9.57%
# Humidity:           15%
# Visibility:         10000 mi
# Wind Speed:         9.57 mph
# Wind Direction:     9°
# Wind Gust:          10.74 mph
#
# Pressure:           1014 hPa
# Sea Level:          1014 hPa
# Ground Level:       787 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 06:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        62.1 F°
# Min and Max Temp:   62.1 F° - 62.1 F°
# Feels Like:         58.95 F°
#
# Clouds:             6.35%
# Humidity:           20%
# Visibility:         10000 mi
# Wind Speed:         6.35 mph
# Wind Direction:     31°
# Wind Gust:          6.51 mph
#
# Pressure:           1017 hPa
# Sea Level:          1017 hPa
# Ground Level:       785 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 09:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        56.19 F°
# Min and Max Temp:   56.19 F° - 56.19 F°
# Feels Like:         52.74 F°
#
# Clouds:             3.4%
# Humidity:           26%
# Visibility:         10000 mi
# Wind Speed:         3.4 mph
# Wind Direction:     55°
# Wind Gust:          3.58 mph
#
# Pressure:           1017 hPa
# Sea Level:          1017 hPa
# Ground Level:       783 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 12:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        54.05 F°
# Min and Max Temp:   54.05 F° - 54.05 F°
# Feels Like:         50.52 F°
#
# Clouds:             3.38%
# Humidity:           29%
# Visibility:         10000 mi
# Wind Speed:         3.38 mph
# Wind Direction:     76°
# Wind Gust:          3.4 mph
#
# Pressure:           1018 hPa
# Sea Level:          1018 hPa
# Ground Level:       783 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 15:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        69.55 F°
# Min and Max Temp:   69.55 F° - 69.55 F°
# Feels Like:         67.19 F°
#
# Clouds:             3.4%
# Humidity:           21%
# Visibility:         10000 mi
# Wind Speed:         3.4 mph
# Wind Direction:     36°
# Wind Gust:          3.83 mph
#
# Pressure:           1017 hPa
# Sea Level:          1017 hPa
# Ground Level:       788 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 18:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        81.01 F°
# Min and Max Temp:   81.01 F° - 81.01 F°
# Feels Like:         79.02 F°
#
# Clouds:             3.49%
# Humidity:           15%
# Visibility:         10000 mi
# Wind Speed:         3.49 mph
# Wind Direction:     339°
# Wind Gust:          6.93 mph
#
# Pressure:           1014 hPa
# Sea Level:          1014 hPa
# Ground Level:       790 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-11 21:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       few clouds
# Temperature:        87.55 F°
# Min and Max Temp:   87.55 F° - 87.55 F°
# Feels Like:         83.88 F°
#
# Clouds:             15.1%
# Humidity:           12%
# Visibility:         10000 mi
# Wind Speed:         15.1 mph
# Wind Direction:     285°
# Wind Gust:          13.42 mph
#
# Pressure:           1011 hPa
# Sea Level:          1011 hPa
# Ground Level:       790 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 00:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       scattered clouds
# Temperature:        87.06 F°
# Min and Max Temp:   87.06 F° - 87.06 F°
# Feels Like:         83.48 F°
#
# Clouds:             4.29%
# Humidity:           12%
# Visibility:         10000 mi
# Wind Speed:         4.29 mph
# Wind Direction:     140°
# Wind Gust:          8.3 mph
#
# Pressure:           1008 hPa
# Sea Level:          1008 hPa
# Ground Level:       788 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 03:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       overcast clouds
# Temperature:        77.92 F°
# Min and Max Temp:   77.92 F° - 77.92 F°
# Feels Like:         76.26 F°
#
# Clouds:             6.38%
# Humidity:           18%
# Visibility:         10000 mi
# Wind Speed:         6.38 mph
# Wind Direction:     329°
# Wind Gust:          12.12 mph
#
# Pressure:           1010 hPa
# Sea Level:          1010 hPa
# Ground Level:       785 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 06:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       broken clouds
# Temperature:        66.04 F°
# Min and Max Temp:   66.04 F° - 66.04 F°
# Feels Like:         63.61 F°
#
# Clouds:             6.29%
# Humidity:           27%
# Visibility:         10000 mi
# Wind Speed:         6.29 mph
# Wind Direction:     50°
# Wind Gust:          6.26 mph
#
# Pressure:           1012 hPa
# Sea Level:          1012 hPa
# Ground Level:       783 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 09:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       scattered clouds
# Temperature:        62.65 F°
# Min and Max Temp:   62.65 F° - 62.65 F°
# Feels Like:         60.12 F°
#
# Clouds:             5.64%
# Humidity:           32%
# Visibility:         10000 mi
# Wind Speed:         5.64 mph
# Wind Direction:     141°
# Wind Gust:          5.64 mph
#
# Pressure:           1013 hPa
# Sea Level:          1013 hPa
# Ground Level:       782 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 12:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       few clouds
# Temperature:        58.89 F°
# Min and Max Temp:   58.89 F° - 58.89 F°
# Feels Like:         56.26 F°
#
# Clouds:             4.34%
# Humidity:           38%
# Visibility:         10000 mi
# Wind Speed:         4.34 mph
# Wind Direction:     126°
# Wind Gust:          4.25 mph
#
# Pressure:           1013 hPa
# Sea Level:          1013 hPa
# Ground Level:       781 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 15:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        74.84 F°
# Min and Max Temp:   74.84 F° - 74.84 F°
# Feels Like:         73 F°
#
# Clouds:             2.53%
# Humidity:           21%
# Visibility:         10000 mi
# Wind Speed:         2.53 mph
# Wind Direction:     172°
# Wind Gust:          5.01 mph
#
# Pressure:           1013 hPa
# Sea Level:          1013 hPa
# Ground Level:       787 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 18:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        85.87 F°
# Min and Max Temp:   85.87 F° - 85.87 F°
# Feels Like:         82.54 F°
#
# Clouds:             12.48%
# Humidity:           13%
# Visibility:         10000 mi
# Wind Speed:         12.48 mph
# Wind Direction:     202°
# Wind Gust:          14.81 mph
#
# Pressure:           1010 hPa
# Sea Level:          1010 hPa
# Ground Level:       789 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-12 21:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       scattered clouds
# Temperature:        89.29 F°
# Min and Max Temp:   89.29 F° - 89.29 F°
# Feels Like:         85.32 F°
#
# Clouds:             17.16%
# Humidity:           10%
# Visibility:         10000 mi
# Wind Speed:         17.16 mph
# Wind Direction:     205°
# Wind Gust:          16.4 mph
#
# Pressure:           1008 hPa
# Sea Level:          1008 hPa
# Ground Level:       788 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 00:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       broken clouds
# Temperature:        88.54 F°
# Min and Max Temp:   88.54 F° - 88.54 F°
# Feels Like:         84.7 F°
#
# Clouds:             19.04%
# Humidity:           10%
# Visibility:         10000 mi
# Wind Speed:         19.04 mph
# Wind Direction:     211°
# Wind Gust:          16.8 mph
#
# Pressure:           1006 hPa
# Sea Level:          1006 hPa
# Ground Level:       786 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 03:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       few clouds
# Temperature:        76.89 F°
# Min and Max Temp:   76.89 F° - 76.89 F°
# Feels Like:         75.04 F°
#
# Clouds:             12.35%
# Humidity:           16%
# Visibility:         10000 mi
# Wind Speed:         12.35 mph
# Wind Direction:     186°
# Wind Gust:          18.14 mph
#
# Pressure:           1008 hPa
# Sea Level:          1008 hPa
# Ground Level:       784 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 06:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        67.08 F°
# Min and Max Temp:   67.08 F° - 67.08 F°
# Feels Like:         64.58 F°
#
# Clouds:             8.72%
# Humidity:           23%
# Visibility:         10000 mi
# Wind Speed:         8.72 mph
# Wind Direction:     187°
# Wind Gust:          8.72 mph
#
# Pressure:           1012 hPa
# Sea Level:          1012 hPa
# Ground Level:       784 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 09:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        62.65 F°
# Min and Max Temp:   62.65 F° - 62.65 F°
# Feels Like:         59.88 F°
#
# Clouds:             5.14%
# Humidity:           27%
# Visibility:         10000 mi
# Wind Speed:         5.14 mph
# Wind Direction:     152°
# Wind Gust:          5.19 mph
#
# Pressure:           1012 hPa
# Sea Level:          1012 hPa
# Ground Level:       782 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 12:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        61.54 F°
# Min and Max Temp:   61.54 F° - 61.54 F°
# Feels Like:         58.75 F°
#
# Clouds:             6.15%
# Humidity:           29%
# Visibility:         10000 mi
# Wind Speed:         6.15 mph
# Wind Direction:     129°
# Wind Gust:          5.84 mph
#
# Pressure:           1013 hPa
# Sea Level:          1013 hPa
# Ground Level:       782 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 15:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        75.6 F°
# Min and Max Temp:   75.6 F° - 75.6 F°
# Feels Like:         73.8 F°
#
# Clouds:             8.52%
# Humidity:           20%
# Visibility:         10000 mi
# Wind Speed:         8.52 mph
# Wind Direction:     185°
# Wind Gust:          15.88 mph
#
# Pressure:           1013 hPa
# Sea Level:          1013 hPa
# Ground Level:       787 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 18:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        83.7 F°
# Min and Max Temp:   83.7 F° - 83.7 F°
# Feels Like:         80.91 F°
#
# Clouds:             19.8%
# Humidity:           15%
# Visibility:         10000 mi
# Wind Speed:         19.8 mph
# Wind Direction:     214°
# Wind Gust:          23.71 mph
#
# Pressure:           1011 hPa
# Sea Level:          1011 hPa
# Ground Level:       789 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-13 21:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        87.85 F°
# Min and Max Temp:   87.85 F° - 87.85 F°
# Feels Like:         84.13 F°
#
# Clouds:             19.71%
# Humidity:           11%
# Visibility:         10000 mi
# Wind Speed:         19.71 mph
# Wind Direction:     212°
# Wind Gust:          20.83 mph
#
# Pressure:           1009 hPa
# Sea Level:          1009 hPa
# Ground Level:       789 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 00:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        87.64 F°
# Min and Max Temp:   87.64 F° - 87.64 F°
# Feels Like:         84 F°
#
# Clouds:             19.17%
# Humidity:           9%
# Visibility:         10000 mi
# Wind Speed:         19.17 mph
# Wind Direction:     208°
# Wind Gust:          17.94 mph
#
# Pressure:           1008 hPa
# Sea Level:          1008 hPa
# Ground Level:       788 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 03:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        74.1 F°
# Min and Max Temp:   74.1 F° - 74.1 F°
# Feels Like:         71.87 F°
#
# Clouds:             9.73%
# Humidity:           14%
# Visibility:         10000 mi
# Wind Speed:         9.73 mph
# Wind Direction:     174°
# Wind Gust:          10.56 mph
#
# Pressure:           1010 hPa
# Sea Level:          1010 hPa
# Ground Level:       784 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 06:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        65.46 F°
# Min and Max Temp:   65.46 F° - 65.46 F°
# Feels Like:         62.8 F°
#
# Clouds:             8.21%
# Humidity:           23%
# Visibility:         10000 mi
# Wind Speed:         8.21 mph
# Wind Direction:     169°
# Wind Gust:          8.03 mph
#
# Pressure:           1014 hPa
# Sea Level:          1014 hPa
# Ground Level:       784 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 09:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        60.44 F°
# Min and Max Temp:   60.44 F° - 60.44 F°
# Feels Like:         57.6 F°
#
# Clouds:             4.43%
# Humidity:           30%
# Visibility:         10000 mi
# Wind Speed:         4.43 mph
# Wind Direction:     198°
# Wind Gust:          4.5 mph
#
# Pressure:           1014 hPa
# Sea Level:          1014 hPa
# Ground Level:       783 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 12:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        59.04 F°
# Min and Max Temp:   59.04 F° - 59.04 F°
# Feels Like:         56.34 F°
#
# Clouds:             6.82%
# Humidity:           36%
# Visibility:         10000 mi
# Wind Speed:         6.82 mph
# Wind Direction:     156°
# Wind Gust:          6.78 mph
#
# Pressure:           1016 hPa
# Sea Level:          1016 hPa
# Ground Level:       783 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 15:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       broken clouds
# Temperature:        74.35 F°
# Min and Max Temp:   74.35 F° - 74.35 F°
# Feels Like:         72.43 F°
#
# Clouds:             7.49%
# Humidity:           20%
# Visibility:         10000 mi
# Wind Speed:         7.49 mph
# Wind Direction:     196°
# Wind Gust:          10.71 mph
#
# Pressure:           1015 hPa
# Sea Level:          1015 hPa
# Ground Level:       788 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 18:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       scattered clouds
# Temperature:        84.29 F°
# Min and Max Temp:   84.29 F° - 84.29 F°
# Feels Like:         81.34 F°
#
# Clouds:             13.78%
# Humidity:           15%
# Visibility:         10000 mi
# Wind Speed:         13.78 mph
# Wind Direction:     231°
# Wind Gust:          17.92 mph
#
# Pressure:           1013 hPa
# Sea Level:          1013 hPa
# Ground Level:       791 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-14 21:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       broken clouds
# Temperature:        88.59 F°
# Min and Max Temp:   88.59 F° - 88.59 F°
# Feels Like:         84.72 F°
#
# Clouds:             16.46%
# Humidity:           13%
# Visibility:         10000 mi
# Wind Speed:         16.46 mph
# Wind Direction:     229°
# Wind Gust:          16.11 mph
#
# Pressure:           1011 hPa
# Sea Level:          1011 hPa
# Ground Level:       791 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-15 00:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       scattered clouds
# Temperature:        88.97 F°
# Min and Max Temp:   88.97 F° - 88.97 F°
# Feels Like:         85.05 F°
#
# Clouds:             11.86%
# Humidity:           11%
# Visibility:         10000 mi
# Wind Speed:         11.86 mph
# Wind Direction:     251°
# Wind Gust:          11.86 mph
#
# Pressure:           1010 hPa
# Sea Level:          1010 hPa
# Ground Level:       789 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-15 03:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       broken clouds
# Temperature:        77 F°
# Min and Max Temp:   77 F° - 77 F°
# Feels Like:         75.06 F°
#
# Clouds:             8.43%
# Humidity:           14%
# Visibility:         10000 mi
# Wind Speed:         8.43 mph
# Wind Direction:     356°
# Wind Gust:          12.15 mph
#
# Pressure:           1012 hPa
# Sea Level:          1012 hPa
# Ground Level:       787 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-15 06:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       broken clouds
# Temperature:        64.36 F°
# Min and Max Temp:   64.36 F° - 64.36 F°
# Feels Like:         61.3 F°
#
# Clouds:             4.09%
# Humidity:           17%
# Visibility:         10000 mi
# Wind Speed:         4.09 mph
# Wind Direction:     141°
# Wind Gust:          4.25 mph
#
# Pressure:           1015 hPa
# Sea Level:          1015 hPa
# Ground Level:       785 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-15 09:00:00-----------
# -----------------------------------------
# Weather:            Clear
# Descripition:       clear sky
# Temperature:        62.33 F°
# Min and Max Temp:   62.33 F° - 62.33 F°
# Feels Like:         59.16 F°
#
# Clouds:             5.01%
# Humidity:           19%
# Visibility:         10000 mi
# Wind Speed:         5.01 mph
# Wind Direction:     145°
# Wind Gust:          4.92 mph
#
# Pressure:           1015 hPa
# Sea Level:          1015 hPa
# Ground Level:       784 hPa
# -----------------------------------------
#
#
# -----------------------------------------
# -----------2022-07-15 12:00:00-----------
# -----------------------------------------
# Weather:            Clouds
# Descripition:       few clouds
# Temperature:        61.16 F°
# Min and Max Temp:   61.16 F° - 61.16 F°
# Feels Like:         58.48 F°
#
# Clouds:             6.55%
# Humidity:           32%
# Visibility:         10000 mi
# Wind Speed:         6.55 mph
# Wind Direction:     153°
# Wind Gust:          6.71 mph
#
# Pressure:           1016 hPa
# Sea Level:          1016 hPa
# Ground Level:       784 hPa
# -----------------------------------------

# %% [markdown]
# ## This is it
#
# I believe that is how the challenge was supposed to be made, for any bugs or suggestions comment in this file repository

# %% [markdown]
# # Test Zone
#
# The following blocks are aside the challenge's objective, <a href=#Project-3-|-Weather-Forecast-API>return to the top</a>

# %% [markdown]
# ## Displaying Requested Data
#
# <a href=##Use-the-Open-Weather-Map-API-to-retrieve-an-up-to-date-weather-forecast-for-this-city>Return to the section that displayed the link to here</a>
#
# <a href=#Project-3-|-Weather-Forecast-API>Return to the top here</a>

# %%
display(forecast_info)
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1657465200,
#    'main': {'temp': 67.44,
#     'feels_like': 64.78,
#     'temp_min': 67.44,
#     'temp_max': 67.44,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 790,
#     'humidity': 19,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.65, 'deg': 78, 'gust': 2.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-10 15:00:00'},
#   {'dt': 1657476000,
#    'main': {'temp': 71.08,
#     'feels_like': 68.63,
#     'temp_min': 71.08,
#     'temp_max': 78.37,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 791,
#     'humidity': 16,
#     'temp_kf': -4.05},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.89, 'deg': 278, 'gust': 10.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-10 18:00:00'},
#   {'dt': 1657486800,
#    'main': {'temp': 78.48,
#     'feels_like': 76.64,
#     'temp_min': 78.48,
#     'temp_max': 84,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 791,
#     'humidity': 13,
#     'temp_kf': -3.07},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 11.01, 'deg': 262, 'gust': 12.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-10 21:00:00'},
#   {'dt': 1657497600,
#    'main': {'temp': 84.94,
#     'feels_like': 81.86,
#     'temp_min': 84.94,
#     'temp_max': 84.94,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 790,
#     'humidity': 9,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.67, 'deg': 312, 'gust': 8.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-11 00:00:00'},
#   {'dt': 1657508400,
#    'main': {'temp': 72.19,
#     'feels_like': 69.82,
#     'temp_min': 72.19,
#     'temp_max': 72.19,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 787,
#     'humidity': 15,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 9.57, 'deg': 9, 'gust': 10.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-11 03:00:00'},
#   {'dt': 1657519200,
#    'main': {'temp': 62.1,
#     'feels_like': 58.95,
#     'temp_min': 62.1,
#     'temp_max': 62.1,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 785,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 6.35, 'deg': 31, 'gust': 6.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-11 06:00:00'},
#   {'dt': 1657530000,
#    'main': {'temp': 56.19,
#     'feels_like': 52.74,
#     'temp_min': 56.19,
#     'temp_max': 56.19,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 783,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.4, 'deg': 55, 'gust': 3.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-11 09:00:00'},
#   {'dt': 1657540800,
#    'main': {'temp': 54.05,
#     'feels_like': 50.52,
#     'temp_min': 54.05,
#     'temp_max': 54.05,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 783,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.38, 'deg': 76, 'gust': 3.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-11 12:00:00'},
#   {'dt': 1657551600,
#    'main': {'temp': 69.55,
#     'feels_like': 67.19,
#     'temp_min': 69.55,
#     'temp_max': 69.55,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 788,
#     'humidity': 21,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 3.4, 'deg': 36, 'gust': 3.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-11 15:00:00'},
#   {'dt': 1657562400,
#    'main': {'temp': 81.01,
#     'feels_like': 79.02,
#     'temp_min': 81.01,
#     'temp_max': 81.01,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 790,
#     'humidity': 15,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.49, 'deg': 339, 'gust': 6.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-11 18:00:00'},
#   {'dt': 1657573200,
#    'main': {'temp': 87.55,
#     'feels_like': 83.88,
#     'temp_min': 87.55,
#     'temp_max': 87.55,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 790,
#     'humidity': 12,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 15.1, 'deg': 285, 'gust': 13.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-11 21:00:00'},
#   {'dt': 1657584000,
#    'main': {'temp': 87.06,
#     'feels_like': 83.48,
#     'temp_min': 87.06,
#     'temp_max': 87.06,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 788,
#     'humidity': 12,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 4.29, 'deg': 140, 'gust': 8.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-12 00:00:00'},
#   {'dt': 1657594800,
#    'main': {'temp': 77.92,
#     'feels_like': 76.26,
#     'temp_min': 77.92,
#     'temp_max': 77.92,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 785,
#     'humidity': 18,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 6.38, 'deg': 329, 'gust': 12.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-12 03:00:00'},
#   {'dt': 1657605600,
#    'main': {'temp': 66.04,
#     'feels_like': 63.61,
#     'temp_min': 66.04,
#     'temp_max': 66.04,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 783,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 6.29, 'deg': 50, 'gust': 6.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-12 06:00:00'},
#   {'dt': 1657616400,
#    'main': {'temp': 62.65,
#     'feels_like': 60.12,
#     'temp_min': 62.65,
#     'temp_max': 62.65,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 782,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 5.64, 'deg': 141, 'gust': 5.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-12 09:00:00'},
#   {'dt': 1657627200,
#    'main': {'temp': 58.89,
#     'feels_like': 56.26,
#     'temp_min': 58.89,
#     'temp_max': 58.89,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 781,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 4.34, 'deg': 126, 'gust': 4.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-12 12:00:00'},
#   {'dt': 1657638000,
#    'main': {'temp': 74.84,
#     'feels_like': 73,
#     'temp_min': 74.84,
#     'temp_max': 74.84,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 787,
#     'humidity': 21,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 2.53, 'deg': 172, 'gust': 5.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-12 15:00:00'},
#   {'dt': 1657648800,
#    'main': {'temp': 85.87,
#     'feels_like': 82.54,
#     'temp_min': 85.87,
#     'temp_max': 85.87,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 789,
#     'humidity': 13,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 12.48, 'deg': 202, 'gust': 14.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-12 18:00:00'},
#   {'dt': 1657659600,
#    'main': {'temp': 89.29,
#     'feels_like': 85.32,
#     'temp_min': 89.29,
#     'temp_max': 89.29,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 788,
#     'humidity': 10,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 17.16, 'deg': 205, 'gust': 16.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-12 21:00:00'},
#   {'dt': 1657670400,
#    'main': {'temp': 88.54,
#     'feels_like': 84.7,
#     'temp_min': 88.54,
#     'temp_max': 88.54,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 786,
#     'humidity': 10,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 19.04, 'deg': 211, 'gust': 16.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-13 00:00:00'},
#   {'dt': 1657681200,
#    'main': {'temp': 76.89,
#     'feels_like': 75.04,
#     'temp_min': 76.89,
#     'temp_max': 76.89,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 784,
#     'humidity': 16,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 12.35, 'deg': 186, 'gust': 18.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-13 03:00:00'},
#   {'dt': 1657692000,
#    'main': {'temp': 67.08,
#     'feels_like': 64.58,
#     'temp_min': 67.08,
#     'temp_max': 67.08,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 784,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 8.72, 'deg': 187, 'gust': 8.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-13 06:00:00'},
#   {'dt': 1657702800,
#    'main': {'temp': 62.65,
#     'feels_like': 59.88,
#     'temp_min': 62.65,
#     'temp_max': 62.65,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 782,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 5.14, 'deg': 152, 'gust': 5.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-13 09:00:00'},
#   {'dt': 1657713600,
#    'main': {'temp': 61.54,
#     'feels_like': 58.75,
#     'temp_min': 61.54,
#     'temp_max': 61.54,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 782,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 6.15, 'deg': 129, 'gust': 5.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-13 12:00:00'},
#   {'dt': 1657724400,
#    'main': {'temp': 75.6,
#     'feels_like': 73.8,
#     'temp_min': 75.6,
#     'temp_max': 75.6,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 787,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 8.52, 'deg': 185, 'gust': 15.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-13 15:00:00'},
#   {'dt': 1657735200,
#    'main': {'temp': 83.7,
#     'feels_like': 80.91,
#     'temp_min': 83.7,
#     'temp_max': 83.7,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 789,
#     'humidity': 15,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 19.8, 'deg': 214, 'gust': 23.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-13 18:00:00'},
#   {'dt': 1657746000,
#    'main': {'temp': 87.85,
#     'feels_like': 84.13,
#     'temp_min': 87.85,
#     'temp_max': 87.85,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 789,
#     'humidity': 11,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 19.71, 'deg': 212, 'gust': 20.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-13 21:00:00'},
#   {'dt': 1657756800,
#    'main': {'temp': 87.64,
#     'feels_like': 84,
#     'temp_min': 87.64,
#     'temp_max': 87.64,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 788,
#     'humidity': 9,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 19.17, 'deg': 208, 'gust': 17.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-14 00:00:00'},
#   {'dt': 1657767600,
#    'main': {'temp': 74.1,
#     'feels_like': 71.87,
#     'temp_min': 74.1,
#     'temp_max': 74.1,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 784,
#     'humidity': 14,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 9.73, 'deg': 174, 'gust': 10.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-14 03:00:00'},
#   {'dt': 1657778400,
#    'main': {'temp': 65.46,
#     'feels_like': 62.8,
#     'temp_min': 65.46,
#     'temp_max': 65.46,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 784,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 8.21, 'deg': 169, 'gust': 8.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-14 06:00:00'},
#   {'dt': 1657789200,
#    'main': {'temp': 60.44,
#     'feels_like': 57.6,
#     'temp_min': 60.44,
#     'temp_max': 60.44,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 783,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 4.43, 'deg': 198, 'gust': 4.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-14 09:00:00'},
#   {'dt': 1657800000,
#    'main': {'temp': 59.04,
#     'feels_like': 56.34,
#     'temp_min': 59.04,
#     'temp_max': 59.04,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 783,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 6.82, 'deg': 156, 'gust': 6.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-14 12:00:00'},
#   {'dt': 1657810800,
#    'main': {'temp': 74.35,
#     'feels_like': 72.43,
#     'temp_min': 74.35,
#     'temp_max': 74.35,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 788,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 7.49, 'deg': 196, 'gust': 10.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-14 15:00:00'},
#   {'dt': 1657821600,
#    'main': {'temp': 84.29,
#     'feels_like': 81.34,
#     'temp_min': 84.29,
#     'temp_max': 84.29,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 791,
#     'humidity': 15,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 13.78, 'deg': 231, 'gust': 17.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-14 18:00:00'},
#   {'dt': 1657832400,
#    'main': {'temp': 88.59,
#     'feels_like': 84.72,
#     'temp_min': 88.59,
#     'temp_max': 88.59,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 791,
#     'humidity': 13,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 16.46, 'deg': 229, 'gust': 16.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-14 21:00:00'},
#   {'dt': 1657843200,
#    'main': {'temp': 88.97,
#     'feels_like': 85.05,
#     'temp_min': 88.97,
#     'temp_max': 88.97,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 789,
#     'humidity': 11,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 11.86, 'deg': 251, 'gust': 11.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-15 00:00:00'},
#   {'dt': 1657854000,
#    'main': {'temp': 77,
#     'feels_like': 75.06,
#     'temp_min': 77,
#     'temp_max': 77,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 787,
#     'humidity': 14,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 8.43, 'deg': 356, 'gust': 12.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-07-15 03:00:00'},
#   {'dt': 1657864800,
#    'main': {'temp': 64.36,
#     'feels_like': 61.3,
#     'temp_min': 64.36,
#     'temp_max': 64.36,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 785,
#     'humidity': 17,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 4.09, 'deg': 141, 'gust': 4.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-15 06:00:00'},
#   {'dt': 1657875600,
#    'main': {'temp': 62.33,
#     'feels_like': 59.16,
#     'temp_min': 62.33,
#     'temp_max': 62.33,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 784,
#     'humidity': 19,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 5.01, 'deg': 145, 'gust': 4.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-15 09:00:00'},
#   {'dt': 1657886400,
#    'main': {'temp': 61.16,
#     'feels_like': 58.48,
#     'temp_min': 61.16,
#     'temp_max': 61.16,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 784,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 6.55, 'deg': 153, 'gust': 6.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-15 12:00:00'}],
#  'city': {'id': 5509151,
#   'name': 'Nevada',
#   'coord': {'lat': 39.2502, 'lon': -116.7512},
#   'country': 'US',
#   'population': 2399532,
#   'timezone': -25200,
#   'sunrise': 1657456160,
#   'sunset': 1657509301}}

# %% [markdown]
# ## Testing Parsed Values
# <a href=#Parse-the-retrieved-information>Return to the section that displayed the link to here</a>
#
# <a href=#Project-3-|-Weather-Forecast-API>Return to the top here</a>

# %%
print(f"""

Country:           {country}
Lat, Lon:          {latitude}, {longtude}
                            
Date and time:     {date_and_time(0)}

Weather:           {weather(0)}
Descripition:      {descripition(0)}

Temperature:       {temperature(0)}F°
Min and Max Temp:  {minimal(0)}F° - {maximum(0)}F°
Feels Like:        {feels_like(0)}F°
                                          

Humidity:          {humidity(0)}%

""")
# Out:
# Country:           US
# Lat, Lon:          39.2502, -116.7512
#
# Date and time:     2022-07-10 15:00:00
#
# Weather:           Clear
# Descripition:      clear sky
#
# Temperature:       67.44F°
# Min and Max Temp:  67.44F° - 67.44F°
# Feels Like:        64.78F°
#
#
# Humidity:          19%
